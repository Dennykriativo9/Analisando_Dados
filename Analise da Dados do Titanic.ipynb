# %%
#Anallise feita pelo: Denilson Salgueiro
#linkedin: Denilson Salgueiro

#importando as bibliotecas
import pandas as pd 
import seaborn as sns
import numpy as np

# %%
#Carregando a Base de dados do Titanic

arquivo =pd.read_csv("titanic.csv",sep=",")

#mudando os nome ou seja traduzindo para o portugues

arquivo.columns =["Id_passageiro","Sobrevivente","Classe","Nome","Sexo","Idade","nº de irmãos","nº de pais/filhos","bilhete","preço do bilhete","nº da cabine","porto_de_embarque"]

# %%
display(arquivo)
# Out:
#      Id_passageiro  Sobrevivente  Classe  \
# 0                1             0       3
# 1                2             1       1
# 2                3             1       3
# 3                4             1       1
# 4                5             0       3
# ..             ...           ...     ...
# 886            887             0       2
# 887            888             1       1
# 888            889             0       3
# 889            890             1       1
# 890            891             0       3
#
#                                                   Nome    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris    male   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                               Heikkinen, Miss. Laina  female   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                             Allen, Mr. William Henry    male   35.0
# ...

# %%
df_dados =pd.DataFrame(arquivo)

# %%
df_dados
# Out:
#      Id_passageiro  Sobrevivente  Classe  \
# 0                1             0       3
# 1                2             1       1
# 2                3             1       3
# 3                4             1       1
# 4                5             0       3
# ..             ...           ...     ...
# 886            887             0       2
# 887            888             1       1
# 888            889             0       3
# 889            890             1       1
# 890            891             0       3
#
#                                                   Nome    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris    male   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                               Heikkinen, Miss. Laina  female   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                             Allen, Mr. William Henry    male   35.0
# ...

# %%
# fazendo uma analise exploratoria para detectar alguns indicadores

df_dados.describe()
# Out:
#        Id_passageiro  Sobrevivente      Classe       Idade  nº de irmãos  \
# count     891.000000    891.000000  891.000000  714.000000    891.000000
# mean      446.000000      0.383838    2.308642   29.699118      0.523008
# std       257.353842      0.486592    0.836071   14.526497      1.102743
# min         1.000000      0.000000    1.000000    0.420000      0.000000
# 25%       223.500000      0.000000    2.000000   20.125000      0.000000
# 50%       446.000000      0.000000    3.000000   28.000000      0.000000
# 75%       668.500000      1.000000    3.000000   38.000000      1.000000
# max       891.000000      1.000000    3.000000   80.000000      8.000000
#
#        nº de pais/filhos  preço do bilhete
# count         891.000000        891.000000
# mean            0.381594         32.204208
# std             0.806057         49.693429
# min             0.000000          0.000000
# 25%             0.000000          7.910400
# 50%             0.000000         14.454200
# ...

# %%
df_dados["Id_passageiro"].count()  # Numero de Passageiros
# Out:
# 891

# %%
df_dados["Sobrevivente"].mode() #
# Out:
# 0    0
# Name: Sobrevivente, dtype: int64

# %%
df_dados["Sobrevivente"].mode() #

# %%
df_dados["preço do bilhete"].sum() # valor arrecadado com vendas de Bilhetes
# Out:
# 28693.9493

# %%
sns.barplot(df_dados,x="Classe",y="Sobrevivente") # Grafico de Barras para relação Classe x Sobreviventes
# Out:
# <Axes: xlabel='Classe', ylabel='Sobrevivente'>

# %%
sns.barplot(df_dados,x="Sobrevivente",y="Sexo")
# Out:
# <Axes: xlabel='Sobrevivente', ylabel='Sexo'>

# %%
sns.barplot(df_dados,x="Sobrevivente",y="Idade")
# Out:
# <Axes: xlabel='Sobrevivente', ylabel='Idade'>

# %%
sns.barplot(df_dados,x="porto_de_embarque",y="Sobrevivente")
# Out:
# <Axes: xlabel='porto_de_embarque', ylabel='Sobrevivente'>
