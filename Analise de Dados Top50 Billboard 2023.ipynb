# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# carregando Dados

arquivo = pd.read_csv("top_50_2023.csv",sep=",")

# %%
df_dados =pd.DataFrame(arquivo)

# %%
df_dados
# Out:
#            artist_name                                         track_name  \
# 0          Miley Cyrus                                            Flowers
# 1                  SZA                                          Kill Bill
# 2         Harry Styles                                          As It Was
# 3            Jung Kook                Seven (feat. Latto) (Explicit Ver.)
# 4       Eslabon Armado                                    Ella Baila Sola
# 5         Taylor Swift                                       Cruel Summer
# 6         Metro Boomin             Creepin' (with The Weeknd & 21 Savage)
# 7                 Rema                      Calm Down (with Selena Gomez)
# 8             Bizarrap              Shakira: Bzrp Music Sessions, Vol. 53
# 9         Taylor Swift                                          Anti-Hero
# 10      Arctic Monkeys                                   I Wanna Be Yours
# 11             KAROL G                                                TQG
# ...

# %%
# Apagando essas Colunas pois nao me servem de utilidade

del df_dados["valence"]
del df_dados["loudness"]
del df_dados["acousticness"]
del df_dados["instrumentalness"]
del df_dados["liveness"]
del df_dados["speechiness"]
del df_dados["key"]
del df_dados["tempo"]
del df_dados["mode"]
del df_dados["duration_ms"]
del df_dados["time_signature"]

# %%
# base de dados limpa

display(df_dados)
# Out:
#            artist_name                                         track_name  \
# 0          Miley Cyrus                                            Flowers
# 1                  SZA                                          Kill Bill
# 2         Harry Styles                                          As It Was
# 3            Jung Kook                Seven (feat. Latto) (Explicit Ver.)
# 4       Eslabon Armado                                    Ella Baila Sola
# 5         Taylor Swift                                       Cruel Summer
# 6         Metro Boomin             Creepin' (with The Weeknd & 21 Savage)
# 7                 Rema                      Calm Down (with Selena Gomez)
# 8             Bizarrap              Shakira: Bzrp Music Sessions, Vol. 53
# 9         Taylor Swift                                          Anti-Hero
# 10      Arctic Monkeys                                   I Wanna Be Yours
# 11             KAROL G                                                TQG
# ...

# %%
df_dados.describe()
# Out:
#        danceability     energy  popularity
# count     50.000000  50.000000   50.000000
# mean       0.662580   0.659880   88.100000
# std        0.123089   0.121499    5.690128
# min        0.445000   0.417000   72.000000
# 25%        0.559500   0.556750   85.000000
# 50%        0.647500   0.678000   89.000000
# 75%        0.776500   0.736500   92.750000
# max        0.911000   0.965000   99.000000

# %%
sns.pairplot(df_dados)

# %%
df_dados.to_csv("Analise de Dados Top50 Billboard.csv") # Salvando a tabela no formato csv para ser rapidamente implementada no PowerBi para criar a visualização dos dados
df_dados.to_html("Analise de Dados Top50 Billboard.html") # salvei em html para poder visualizar a tabela antes de fazer o dashboard
